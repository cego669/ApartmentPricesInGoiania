# %% [markdown]
# # Base model with statistics from different sectors of Goiânia
#
# For this model further feature engineering was performed. The clustering of the latitude and longitude of the apartments was performed, so we can be able to calculate useful summary statistics from the numeric features and also from the target (price of the apartments). Additionaly, from the latitude and longitude the distance from different shopping centers in Goiânia were calculated to be used as features.

# %% [markdown]
# ### Loading data

# %%
import pandas as pd

data = pd.read_csv("C:/Users/cego/OneDrive/Área de Trabalho/Projetos Pessoais/Projeto, apartment prices v2/4_img_feature_extraction/data.csv",
                   sep="|")
data.dropna(subset=["lat", "long"], inplace=True)
data.head()
# Out:
#                                         id     price  condo_fee    iptu  \
# 0   62750619205425081544300816117885861273  949900.0      790.0  1900.0
# 1  302678336848826931249389939487192177877  760000.0        NaN     NaN
# 2  130359292211767838527233708900928593543  350000.0      270.0   250.0
# 4  200978065182550317495009592604134775241  624700.0      500.0   900.0
# 5    9796372657926373412148234085533873844  374813.0        NaN     NaN
#
#                                              address  floorSize  \
# 0       Rua C238, 100 - Jardim América, Goiânia - GO      130.0
# 1          Rua T 30, S/N - Setor Bueno, Goiânia - GO       90.0
# 2    Avenida Marialva, 435 - Vila Rosa, Goiânia - GO       57.0
# 4  Avenida Dona Maria Cardoso, 735 - Parque Amazô...       72.0
# 5      Rua Dona Isoleta, 3 - Vila Rosa, Goiânia - GO       61.0
#
#    numberOfRooms  numberOfBathroomsTotal  numberOfParkingSpaces  floorLevel  \
# 0            3.0                     4.0                    2.0        24.0
# 1            2.5                     2.5                    1.5         NaN
# 2            2.0                     1.0                    1.0        19.0
# 4            2.0                     1.0                    1.0         8.0
# 5            2.0                     2.0                    1.0         7.0
#
#    ...  feature_maps_503  feature_maps_504  feature_maps_505  \
# 0  ...          0.127765          3.524587          1.041046
# 1  ...          0.515701          3.463290          0.394959
# 2  ...          0.229476          2.309388          0.158572
# 4  ...          0.203433          1.041208          0.361618
# 5  ...          0.000000          0.899192          0.001990
#
#    feature_maps_506  feature_maps_507  feature_maps_508  feature_maps_509  \
# 0          0.016919          0.452591          3.309776          0.982112
# 1          0.283912          0.211381          0.619300          1.635983
# 2          0.197296          0.073967          0.820991          1.299795
# 4          0.499424          0.165279          0.054856          2.148610
# 5          0.930970          0.025143          0.425353          1.415770
#
#    feature_maps_510  feature_maps_511  feature_maps_512
# 0          0.333408          0.894974          0.448568
# 1          0.501667          0.608028          0.017285
# 2          0.337664          0.174766          0.416028
# 4          0.781782          0.042805          0.157398
# 5          1.017306          0.223564          0.723442
#
# [5 rows x 593 columns]

# %% [markdown]
# ### Distance to shopping centers

# %%
from haversine import haversine

shoppings = {"Passeio_das_Aguas": (-16.62935338717902, -49.27864911348494),
            "Flamboyant": (-16.709983713886288, -49.237018433761605),
            "Portal_Sul": (-16.770457543653993, -49.35181898957849),
            "Goiânia": (-16.70811433888118, -49.27281973376176),
            "Cerrado": (-16.665992404732286, -49.308465857660444),
            "Portal": (-16.654047808420035, -49.32928694540062),
            "Plaza_Doro": (-16.70722528961973, -49.32804553190786),
            "Cidade_Jardim": (-16.682721816436608, -49.31411186259885),
            "Perimetral_Open_Mall": (-16.642368044349382, -49.307910909152895),
            "Araguaia": (-16.658321034298336, -49.25941657000837),
            "Bouganville": (-16.694169294923878, -49.265424718418366),
            "Buriti": (-16.74178147681141, -49.27701120492441),
            "Lozandes": (-16.692997718702827, -49.22246682530371),
            "Orion_Complex": (-16.69664826311222, -49.270025781651654),
            "Republica": (-16.67823083437392, -49.26693911841769),
            "Anhanguera": (-16.673622640794598, -49.2555401644532),
            "Gallo": (-16.661639216531704, -49.25507395766126),
            "Estacao_Goiania": (-16.66110701599241, -49.261788203072975),
            "Buena_Vista": (-16.710339841635147, -49.26776864725288)}

for key in shoppings.keys():
    data[f"dist_{key}"] = data.apply(lambda row: haversine((row.lat, row.long),
                                                          shoppings[key]), axis=1)

# %% [markdown]
# ### Preparing training and testing data

# %%
import numpy as np

X = data.drop(columns=["id", "price", "address", "complete_description", "description_length"] + [col for col in data.columns if "feature_maps_" in col])
y = np.log10(data["price"].values)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test, id_train, id_test, = train_test_split(X, y, data["id"],
                                                                        test_size=.2,
                                                                        random_state=669)

# %% [markdown]
# ### Clustering over the latitude and longitude

# %%
from sklearn.cluster import KMeans

inertia_values = {"k": [],
                  "inertia": []}
for k in range(2, 30):
    for _ in range(15):
        kmeans = KMeans(n_clusters=k, max_iter=10**3, n_init="auto")
        _ = kmeans.fit_predict(X_train[["lat", "long"]])
        inertia_values["k"].append(k)
        inertia_values["inertia"].append(kmeans.inertia_)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.violinplot(pd.DataFrame(inertia_values), x="k", y="inertia")
plt.show()

# %%
kmeans = KMeans(n_clusters=15, max_iter=10**3, n_init="auto")

X_train["lat_long_cluster"] = kmeans.fit_predict(X_train[["lat", "long"]])
X_train["lat_long_cluster"] = X_train["lat_long_cluster"].apply(lambda x: f"cluster_{str(x)}")

X_test["lat_long_cluster"] = kmeans.predict(X_test[["lat", "long"]])
X_test["lat_long_cluster"] = X_test["lat_long_cluster"].apply(lambda x: f"cluster_{str(x)}")

sns.scatterplot(X_train, x="lat", y="long", hue="lat_long_cluster")
plt.show()

# %%
X_train.drop(columns=["lat", "long"], inplace=True)
X_test.drop(columns=["lat", "long"], inplace=True)

# %%
X_train.columns
# Out:
# Index(['condo_fee', 'iptu', 'floorSize', 'numberOfRooms',
#        'numberOfBathroomsTotal', 'numberOfParkingSpaces', 'floorLevel',
#        'Cat_pool', 'Cat_elevator', 'Cat_barbecueGrill', 'Cat_gatedCommunity',
#        'Cat_gym', 'Cat_gourmetSpace', 'Cat_garden', 'Cat_playground',
#        'Cat_partyHall', 'Cat_laundry', 'Cat_disabledAccess', 'Cat_coworking',
#        'Cat_electronicGate', 'Cat_sauna', 'Cat_spa', 'Cat_petsAllowed',
#        'Cat_airConditioning', 'Cat_gourmetBalcony', 'Cat_sportsCourt',
#        'Cat_bicyclesPlace', 'Cat_concierge24h', 'Cat_americanKitchen',
#        'Cat_balcony', 'Cat_intercom', 'Cat_serviceArea', 'Cat_largeKitchen',
#        'Cat_furnished', 'Cat_kitchen', 'Cat_adultGameRoom', 'Cat_deposit',
#        'Cat_watchman', 'Cat_security24Hours', 'Cat_bedroomWardrobe',
#        'Cat_internetAccess', 'Cat_closet', 'Cat_gourmetKitchen',
#        'Cat_electricGenerator', 'Cat_alarmSystem', 'Cat_toysPlace',
#        'Cat_cinema', 'Cat_heating', 'Cat_builtinWardrobe',
#        'Cat_kitchenCabinets', 'Cat_safetyCircuit', 'Cat_garage',
#        'Cat_tennisCourt', 'Cat_greenSpace', 'Cat_squash', 'Cat_fireplace',
#        'Cat_homeOffice', 'Cat_bathroomCabinets', 'Cat_gasShower',
#        'Cat_blindexBox', 'Cat_reception', 'Cat_cableTv', 'Cat_bathtub',
#        'Cat_privatePool', 'Cat_backyard', 'Cat_grass', 'Cat_largeWindow',
#        'Cat_naturalVentilation', 'Cat_cooker', 'Cat_hikingTrail',
#        'Cat_panoramicView', 'Cat_massage', 'Cat_freezer', 'total_cat',
#        'dist_Passeio_das_Aguas', 'dist_Flamboyant', 'dist_Portal_Sul',
#        'dist_Goiânia', 'dist_Cerrado', 'dist_Portal', 'dist_Plaza_Doro',
#        'dist_Cidade_Jardim', 'dist_Perimetral_Open_Mall', 'dist_Araguaia',
#        'dist_Bouganville', 'dist_Buriti', 'dist_Lozandes',
#        'dist_Orion_Complex', 'dist_Republica', 'dist_Anhanguera', 'dist_Gallo',
#        'dist_Estacao_Goiania', 'dist_Buena_Vista', 'lat_long_cluster'],
#       dtype='object')

# %%
cols_to_log = ['floorLevel', 'condo_fee', 'iptu',
               'floorSize', 'total_cat']
for col in cols_to_log:
    X[col] = np.log10(X[col] + 1)

# %% [markdown]
# ### Preparing regression model and performing hyperparameter tuning

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import TruncatedSVD
from StatisticsFromFeatures import StatisticsFromFeatures
from StatisticsFromTarget import StatisticsFromTarget
from sklearn.ensemble import HistGradientBoostingRegressor


dist_cols = [col for col in X.columns if "dist_" in col]

cat_cols = [col for col in data.columns if "Cat_" in col]

num_cols = ['floorLevel','condo_fee', 'iptu', 'floorSize',
              'numberOfRooms', 'numberOfBathroomsTotal',
              'numberOfParkingSpaces', 'total_cat']

transformer = ColumnTransformer([("dist", TruncatedSVD(n_components=3), dist_cols),
                                ("cat", TruncatedSVD(n_components=10), cat_cols),
                                ("stats_from_features", StatisticsFromFeatures(["lat_long_cluster"], num_cols), ["lat_long_cluster"] + num_cols),
                                ("stats_from_target", StatisticsFromTarget(["lat_long_cluster"]), ["lat_long_cluster"])],
                                remainder="passthrough")

model = HistGradientBoostingRegressor(max_iter=1000)
model_pipe = Pipeline([("preprocessing", transformer),
                      ("model", model)])

# %%
from sklearn.metrics import make_scorer
from skopt.space import Real, Integer, Categorical
from skopt import BayesSearchCV

param_distributions = {"model__learning_rate": Real(1e-5, 1, prior="log-uniform"),
                      "model__max_leaf_nodes": Integer(3, 150, prior="uniform"),
                      "model__l2_regularization": Real(1e-6, 1, prior="log-uniform"),
                      "model__min_samples_leaf": Integer(5, 600, prior="uniform"),
                      "model__loss": Categorical(["squared_error", "absolute_error"])}

def scoring(y_true, y_pred):
    y_true = 10**y_true
    y_pred = 10**y_pred
    pct_error = np.abs(y_pred - y_true)/y_true
    return np.mean(pct_error <= .2)

bs_model = BayesSearchCV(model_pipe,
                           param_distributions,
                           cv=3,
                           n_iter=100,
                           scoring=make_scorer(scoring),
                           n_jobs=1,
                           random_state=668,
                           verbose=10)

# %%
np.int = int
bs_model.fit(X_train, y_train)
y_pred = bs_model.predict(X_test)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=0.015045555560974122, model__learning_rate=0.10613472205446763, model__loss=squared_error, model__max_leaf_nodes=131, model__min_samples_leaf=349
# [CV 1/3; 1/1] END model__l2_regularization=0.015045555560974122, model__learning_rate=0.10613472205446763, model__loss=squared_error, model__max_leaf_nodes=131, model__min_samples_leaf=349;, score=0.689 total time=   4.7s
# [CV 2/3; 1/1] START model__l2_regularization=0.015045555560974122, model__learning_rate=0.10613472205446763, model__loss=squared_error, model__max_leaf_nodes=131, model__min_samples_leaf=349
# [CV 2/3; 1/1] END model__l2_regularization=0.015045555560974122, model__learning_rate=0.10613472205446763, model__loss=squared_error, model__max_leaf_nodes=131, model__min_samples_leaf=349;, score=0.692 total time=   5.3s
# [CV 3/3; 1/1] START model__l2_regularization=0.015045555560974122, model__learning_rate=0.10613472205446763, model__loss=squared_error, model__max_leaf_nodes=131, model__min_samples_leaf=349
# [CV 3/3; 1/1] END model__l2_regularization=0.015045555560974122, model__learning_rate=0.10613472205446763, model__loss=squared_error, model__max_leaf_nodes=131, model__min_samples_leaf=349;, score=0.717 total time=   5.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=0.01875105252865337, model__learning_rate=0.008544826432936926, model__loss=squared_error, model__max_leaf_nodes=119, model__min_samples_leaf=225
# [CV 1/3; 1/1] END model__l2_regularization=0.01875105252865337, model__learning_rate=0.008544826432936926, model__loss=squared_error, model__max_leaf_nodes=119, model__min_samples_leaf=225;, score=0.690 total time=   7.2s
# [CV 2/3; 1/1] START model__l2_regularization=0.01875105252865337, model__learning_rate=0.008544826432936926, model__loss=squared_error, model__max_leaf_nodes=119, model__min_samples_leaf=225
# [CV 2/3; 1/1] END model__l2_regularization=0.01875105252865337, model__learning_rate=0.008544826432936926, model__loss=squared_error, model__max_leaf_nodes=119, model__min_samples_leaf=225;, score=0.698 total time=   6.8s
# [CV 3/3; 1/1] START model__l2_regularization=0.01875105252865337, model__learning_rate=0.008544826432936926, model__loss=squared_error, model__max_leaf_nodes=119, model__min_samples_leaf=225
# [CV 3/3; 1/1] END model__l2_regularization=0.01875105252865337, model__learning_rate=0.008544826432936926, model__loss=squared_error, model__max_leaf_nodes=119, model__min_samples_leaf=225;, score=0.711 total time=   7.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0583002405226634e-05, model__learning_rate=0.002458553140691275, model__loss=absolute_error, model__max_leaf_nodes=85, model__min_samples_leaf=145
# [CV 1/3; 1/1] END model__l2_regularization=1.0583002405226634e-05, model__learning_rate=0.002458553140691275, model__loss=absolute_error, model__max_leaf_nodes=85, model__min_samples_leaf=145;, score=0.627 total time=  11.3s
# [CV 2/3; 1/1] START model__l2_regularization=1.0583002405226634e-05, model__learning_rate=0.002458553140691275, model__loss=absolute_error, model__max_leaf_nodes=85, model__min_samples_leaf=145
# [CV 2/3; 1/1] END model__l2_regularization=1.0583002405226634e-05, model__learning_rate=0.002458553140691275, model__loss=absolute_error, model__max_leaf_nodes=85, model__min_samples_leaf=145;, score=0.636 total time=  10.7s
# [CV 3/3; 1/1] START model__l2_regularization=1.0583002405226634e-05, model__learning_rate=0.002458553140691275, model__loss=absolute_error, model__max_leaf_nodes=85, model__min_samples_leaf=145
# [CV 3/3; 1/1] END model__l2_regularization=1.0583002405226634e-05, model__learning_rate=0.002458553140691275, model__loss=absolute_error, model__max_leaf_nodes=85, model__min_samples_leaf=145;, score=0.640 total time=  10.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=9.516320036529668e-06, model__learning_rate=0.0017434823932432411, model__loss=squared_error, model__max_leaf_nodes=5, model__min_samples_leaf=312
# [CV 1/3; 1/1] END model__l2_regularization=9.516320036529668e-06, model__learning_rate=0.0017434823932432411, model__loss=squared_error, model__max_leaf_nodes=5, model__min_samples_leaf=312;, score=0.545 total time=   3.5s
# [CV 2/3; 1/1] START model__l2_regularization=9.516320036529668e-06, model__learning_rate=0.0017434823932432411, model__loss=squared_error, model__max_leaf_nodes=5, model__min_samples_leaf=312
# [CV 2/3; 1/1] END model__l2_regularization=9.516320036529668e-06, model__learning_rate=0.0017434823932432411, model__loss=squared_error, model__max_leaf_nodes=5, model__min_samples_leaf=312;, score=0.525 total time=   3.2s
# [CV 3/3; 1/1] START model__l2_regularization=9.516320036529668e-06, model__learning_rate=0.0017434823932432411, model__loss=squared_error, model__max_leaf_nodes=5, model__min_samples_leaf=312
# [CV 3/3; 1/1] END model__l2_regularization=9.516320036529668e-06, model__learning_rate=0.0017434823932432411, model__loss=squared_error, model__max_leaf_nodes=5, model__min_samples_leaf=312;, score=0.537 total time=   3.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=0.008031521635829715, model__learning_rate=0.0007848454165504987, model__loss=squared_error, model__max_leaf_nodes=145, model__min_samples_leaf=69
# [CV 1/3; 1/1] END model__l2_regularization=0.008031521635829715, model__learning_rate=0.0007848454165504987, model__loss=squared_error, model__max_leaf_nodes=145, model__min_samples_leaf=69;, score=0.441 total time=  18.0s
# [CV 2/3; 1/1] START model__l2_regularization=0.008031521635829715, model__learning_rate=0.0007848454165504987, model__loss=squared_error, model__max_leaf_nodes=145, model__min_samples_leaf=69
# [CV 2/3; 1/1] END model__l2_regularization=0.008031521635829715, model__learning_rate=0.0007848454165504987, model__loss=squared_error, model__max_leaf_nodes=145, model__min_samples_leaf=69;, score=0.426 total time=  17.3s
# [CV 3/3; 1/1] START model__l2_regularization=0.008031521635829715, model__learning_rate=0.0007848454165504987, model__loss=squared_error, model__max_leaf_nodes=145, model__min_samples_leaf=69
# [CV 3/3; 1/1] END model__l2_regularization=0.008031521635829715, model__learning_rate=0.0007848454165504987, model__loss=squared_error, model__max_leaf_nodes=145, model__min_samples_leaf=69;, score=0.429 total time=  19.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=0.000817952206945488, model__learning_rate=3.2720751959764995e-05, model__loss=squared_error, model__max_leaf_nodes=73, model__min_samples_leaf=28
# [CV 1/3; 1/1] END model__l2_regularization=0.000817952206945488, model__learning_rate=3.2720751959764995e-05, model__loss=squared_error, model__max_leaf_nodes=73, model__min_samples_leaf=28;, score=0.250 total time=  36.6s
# [CV 2/3; 1/1] START model__l2_regularization=0.000817952206945488, model__learning_rate=3.2720751959764995e-05, model__loss=squared_error, model__max_leaf_nodes=73, model__min_samples_leaf=28
# [CV 2/3; 1/1] END model__l2_regularization=0.000817952206945488, model__learning_rate=3.2720751959764995e-05, model__loss=squared_error, model__max_leaf_nodes=73, model__min_samples_leaf=28;, score=0.235 total time=  36.0s
# [CV 3/3; 1/1] START model__l2_regularization=0.000817952206945488, model__learning_rate=3.2720751959764995e-05, model__loss=squared_error, model__max_leaf_nodes=73, model__min_samples_leaf=28
# [CV 3/3; 1/1] END model__l2_regularization=0.000817952206945488, model__learning_rate=3.2720751959764995e-05, model__loss=squared_error, model__max_leaf_nodes=73, model__min_samples_leaf=28;, score=0.233 total time=  35.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=0.0565291205535205, model__learning_rate=0.02837165145086981, model__loss=squared_error, model__max_leaf_nodes=145, model__min_samples_leaf=47
# [CV 1/3; 1/1] END model__l2_regularization=0.0565291205535205, model__learning_rate=0.02837165145086981, model__loss=squared_error, model__max_leaf_nodes=145, model__min_samples_leaf=47;, score=0.747 total time=  25.0s
# [CV 2/3; 1/1] START model__l2_regularization=0.0565291205535205, model__learning_rate=0.02837165145086981, model__loss=squared_error, model__max_leaf_nodes=145, model__min_samples_leaf=47
# [CV 2/3; 1/1] END model__l2_regularization=0.0565291205535205, model__learning_rate=0.02837165145086981, model__loss=squared_error, model__max_leaf_nodes=145, model__min_samples_leaf=47;, score=0.734 total time=  25.1s
# [CV 3/3; 1/1] START model__l2_regularization=0.0565291205535205, model__learning_rate=0.02837165145086981, model__loss=squared_error, model__max_leaf_nodes=145, model__min_samples_leaf=47
# [CV 3/3; 1/1] END model__l2_regularization=0.0565291205535205, model__learning_rate=0.02837165145086981, model__loss=squared_error, model__max_leaf_nodes=145, model__min_samples_leaf=47;, score=0.749 total time=  24.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=6.784168297479136e-06, model__learning_rate=0.009102866871985553, model__loss=absolute_error, model__max_leaf_nodes=111, model__min_samples_leaf=444
# [CV 1/3; 1/1] END model__l2_regularization=6.784168297479136e-06, model__learning_rate=0.009102866871985553, model__loss=absolute_error, model__max_leaf_nodes=111, model__min_samples_leaf=444;, score=0.653 total time=   4.0s
# [CV 2/3; 1/1] START model__l2_regularization=6.784168297479136e-06, model__learning_rate=0.009102866871985553, model__loss=absolute_error, model__max_leaf_nodes=111, model__min_samples_leaf=444
# [CV 2/3; 1/1] END model__l2_regularization=6.784168297479136e-06, model__learning_rate=0.009102866871985553, model__loss=absolute_error, model__max_leaf_nodes=111, model__min_samples_leaf=444;, score=0.648 total time=   4.2s
# [CV 3/3; 1/1] START model__l2_regularization=6.784168297479136e-06, model__learning_rate=0.009102866871985553, model__loss=absolute_error, model__max_leaf_nodes=111, model__min_samples_leaf=444
# [CV 3/3; 1/1] END model__l2_regularization=6.784168297479136e-06, model__learning_rate=0.009102866871985553, model__loss=absolute_error, model__max_leaf_nodes=111, model__min_samples_leaf=444;, score=0.656 total time=   4.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=0.0020256457056441737, model__learning_rate=0.06278838288140219, model__loss=squared_error, model__max_leaf_nodes=46, model__min_samples_leaf=154
# [CV 1/3; 1/1] END model__l2_regularization=0.0020256457056441737, model__learning_rate=0.06278838288140219, model__loss=squared_error, model__max_leaf_nodes=46, model__min_samples_leaf=154;, score=0.729 total time=   8.4s
# [CV 2/3; 1/1] START model__l2_regularization=0.0020256457056441737, model__learning_rate=0.06278838288140219, model__loss=squared_error, model__max_leaf_nodes=46, model__min_samples_leaf=154
# [CV 2/3; 1/1] END model__l2_regularization=0.0020256457056441737, model__learning_rate=0.06278838288140219, model__loss=squared_error, model__max_leaf_nodes=46, model__min_samples_leaf=154;, score=0.723 total time=   9.3s
# [CV 3/3; 1/1] START model__l2_regularization=0.0020256457056441737, model__learning_rate=0.06278838288140219, model__loss=squared_error, model__max_leaf_nodes=46, model__min_samples_leaf=154
# [CV 3/3; 1/1] END model__l2_regularization=0.0020256457056441737, model__learning_rate=0.06278838288140219, model__loss=squared_error, model__max_leaf_nodes=46, model__min_samples_leaf=154;, score=0.732 total time=   8.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=7.905649082933369e-06, model__learning_rate=0.00035919968287285764, model__loss=absolute_error, model__max_leaf_nodes=23, model__min_samples_leaf=168
# [CV 1/3; 1/1] END model__l2_regularization=7.905649082933369e-06, model__learning_rate=0.00035919968287285764, model__loss=absolute_error, model__max_leaf_nodes=23, model__min_samples_leaf=168;, score=0.350 total time=   8.9s
# [CV 2/3; 1/1] START model__l2_regularization=7.905649082933369e-06, model__learning_rate=0.00035919968287285764, model__loss=absolute_error, model__max_leaf_nodes=23, model__min_samples_leaf=168
# [CV 2/3; 1/1] END model__l2_regularization=7.905649082933369e-06, model__learning_rate=0.00035919968287285764, model__loss=absolute_error, model__max_leaf_nodes=23, model__min_samples_leaf=168;, score=0.338 total time=   8.7s
# [CV 3/3; 1/1] START model__l2_regularization=7.905649082933369e-06, model__learning_rate=0.00035919968287285764, model__loss=absolute_error, model__max_leaf_nodes=23, model__min_samples_leaf=168
# [CV 3/3; 1/1] END model__l2_regularization=7.905649082933369e-06, model__learning_rate=0.00035919968287285764, model__loss=absolute_error, model__max_leaf_nodes=23, model__min_samples_leaf=168;, score=0.334 total time=   8.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.661 total time=   2.5s
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.664 total time=   2.6s
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.682 total time=   2.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=0.0002661384380378679, model__learning_rate=0.01400900576835117, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=0.0002661384380378679, model__learning_rate=0.01400900576835117, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.656 total time=   2.6s
# [CV 2/3; 1/1] START model__l2_regularization=0.0002661384380378679, model__learning_rate=0.01400900576835117, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=0.0002661384380378679, model__learning_rate=0.01400900576835117, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.661 total time=   2.6s
# [CV 3/3; 1/1] START model__l2_regularization=0.0002661384380378679, model__learning_rate=0.01400900576835117, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=0.0002661384380378679, model__learning_rate=0.01400900576835117, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.681 total time=   2.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=squared_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=squared_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.655 total time=   2.4s
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=squared_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=squared_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.623 total time=   2.6s
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=squared_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=squared_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.643 total time=   2.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=0.23131068755307518, model__learning_rate=0.1286568038082024, model__loss=absolute_error, model__max_leaf_nodes=115, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=0.23131068755307518, model__learning_rate=0.1286568038082024, model__loss=absolute_error, model__max_leaf_nodes=115, model__min_samples_leaf=5;, score=0.735 total time= 1.3min
# [CV 2/3; 1/1] START model__l2_regularization=0.23131068755307518, model__learning_rate=0.1286568038082024, model__loss=absolute_error, model__max_leaf_nodes=115, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=0.23131068755307518, model__learning_rate=0.1286568038082024, model__loss=absolute_error, model__max_leaf_nodes=115, model__min_samples_leaf=5;, score=0.734 total time= 1.2min
# [CV 3/3; 1/1] START model__l2_regularization=0.23131068755307518, model__learning_rate=0.1286568038082024, model__loss=absolute_error, model__max_leaf_nodes=115, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=0.23131068755307518, model__learning_rate=0.1286568038082024, model__loss=absolute_error, model__max_leaf_nodes=115, model__min_samples_leaf=5;, score=0.747 total time= 1.2min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.05605319070471153, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=600
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.05605319070471153, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=600;, score=0.662 total time=   3.1s
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.05605319070471153, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=600
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.05605319070471153, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=600;, score=0.669 total time=   3.2s
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.05605319070471153, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=600
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.05605319070471153, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=600;, score=0.682 total time=   3.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.04571643524793545, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.04571643524793545, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.682 total time=   2.4s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.04571643524793545, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.04571643524793545, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.677 total time=   2.4s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.04571643524793545, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.04571643524793545, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.699 total time=   2.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.2532634568741417, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.2532634568741417, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.694 total time=   2.3s
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.2532634568741417, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.2532634568741417, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.693 total time=   2.4s
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.2532634568741417, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.2532634568741417, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.706 total time=   2.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.058461660714083694, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.058461660714083694, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.744 total time= 1.2min
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.058461660714083694, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.058461660714083694, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.742 total time= 1.1min
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.058461660714083694, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.058461660714083694, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.758 total time= 1.1min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.04574874041046213, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.04574874041046213, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.741 total time= 1.2min
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.04574874041046213, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.04574874041046213, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.750 total time= 1.2min
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.04574874041046213, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.04574874041046213, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.752 total time= 1.2min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=2.0316225482968255e-05, model__learning_rate=0.018035703338836383, model__loss=squared_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=2.0316225482968255e-05, model__learning_rate=0.018035703338836383, model__loss=squared_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.663 total time=   2.0s
# [CV 2/3; 1/1] START model__l2_regularization=2.0316225482968255e-05, model__learning_rate=0.018035703338836383, model__loss=squared_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=2.0316225482968255e-05, model__learning_rate=0.018035703338836383, model__loss=squared_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.654 total time=   2.1s
# [CV 3/3; 1/1] START model__l2_regularization=2.0316225482968255e-05, model__learning_rate=0.018035703338836383, model__loss=squared_error, model__max_leaf_nodes=3, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=2.0316225482968255e-05, model__learning_rate=0.018035703338836383, model__loss=squared_error, model__max_leaf_nodes=3, model__min_samples_leaf=5;, score=0.681 total time=   2.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.061356238245413836, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=105
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.061356238245413836, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=105;, score=0.724 total time=  12.9s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.061356238245413836, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=105
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.061356238245413836, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=105;, score=0.728 total time=  13.3s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.061356238245413836, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=105
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.061356238245413836, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=105;, score=0.737 total time=  13.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.576 total time= 1.6min
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.581 total time= 1.6min
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.590 total time= 1.6min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.052116182405750534, model__loss=squared_error, model__max_leaf_nodes=103, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.052116182405750534, model__loss=squared_error, model__max_leaf_nodes=103, model__min_samples_leaf=5;, score=0.744 total time=  50.8s
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.052116182405750534, model__loss=squared_error, model__max_leaf_nodes=103, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.052116182405750534, model__loss=squared_error, model__max_leaf_nodes=103, model__min_samples_leaf=5;, score=0.746 total time=  46.5s
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.052116182405750534, model__loss=squared_error, model__max_leaf_nodes=103, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.052116182405750534, model__loss=squared_error, model__max_leaf_nodes=103, model__min_samples_leaf=5;, score=0.756 total time=  51.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=600
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=600;, score=0.651 total time=   2.3s
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=600
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=600;, score=0.652 total time=   2.5s
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=600
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=1.0, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=600;, score=0.676 total time=   2.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.012645819655492656, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.012645819655492656, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.741 total time= 1.4min
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.012645819655492656, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.012645819655492656, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.747 total time= 1.3min
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.012645819655492656, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.012645819655492656, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.759 total time= 1.3min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=0.0192206523488408, model__learning_rate=0.08844048188870636, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=0.0192206523488408, model__learning_rate=0.08844048188870636, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.738 total time=  38.9s
# [CV 2/3; 1/1] START model__l2_regularization=0.0192206523488408, model__learning_rate=0.08844048188870636, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=0.0192206523488408, model__learning_rate=0.08844048188870636, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.742 total time=  38.5s
# [CV 3/3; 1/1] START model__l2_regularization=0.0192206523488408, model__learning_rate=0.08844048188870636, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=0.0192206523488408, model__learning_rate=0.08844048188870636, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.756 total time=  38.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.12507968241439865, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=600
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.12507968241439865, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=600;, score=0.663 total time=   2.2s
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.12507968241439865, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=600
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.12507968241439865, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=600;, score=0.662 total time=   2.3s
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.12507968241439865, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=600
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.12507968241439865, model__loss=absolute_error, model__max_leaf_nodes=3, model__min_samples_leaf=600;, score=0.683 total time=   2.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.008304191105240024, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.008304191105240024, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.742 total time= 1.5min
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.008304191105240024, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.008304191105240024, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.739 total time= 1.5min
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.008304191105240024, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.008304191105240024, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.746 total time= 1.5min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.01751238662895677, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.01751238662895677, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.745 total time= 1.4min
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.01751238662895677, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.01751238662895677, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.740 total time= 1.4min
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.01751238662895677, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.01751238662895677, model__loss=absolute_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.754 total time= 1.4min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=2.8834936088926936e-06, model__learning_rate=0.010796363506280283, model__loss=absolute_error, model__max_leaf_nodes=109, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=2.8834936088926936e-06, model__learning_rate=0.010796363506280283, model__loss=absolute_error, model__max_leaf_nodes=109, model__min_samples_leaf=5;, score=0.733 total time= 1.2min
# [CV 2/3; 1/1] START model__l2_regularization=2.8834936088926936e-06, model__learning_rate=0.010796363506280283, model__loss=absolute_error, model__max_leaf_nodes=109, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=2.8834936088926936e-06, model__learning_rate=0.010796363506280283, model__loss=absolute_error, model__max_leaf_nodes=109, model__min_samples_leaf=5;, score=0.740 total time= 1.1min
# [CV 3/3; 1/1] START model__l2_regularization=2.8834936088926936e-06, model__learning_rate=0.010796363506280283, model__loss=absolute_error, model__max_leaf_nodes=109, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=2.8834936088926936e-06, model__learning_rate=0.010796363506280283, model__loss=absolute_error, model__max_leaf_nodes=109, model__min_samples_leaf=5;, score=0.739 total time= 1.1min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.08417312447616138, model__loss=absolute_error, model__max_leaf_nodes=85, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.08417312447616138, model__loss=absolute_error, model__max_leaf_nodes=85, model__min_samples_leaf=5;, score=0.742 total time=  51.4s
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.08417312447616138, model__loss=absolute_error, model__max_leaf_nodes=85, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.08417312447616138, model__loss=absolute_error, model__max_leaf_nodes=85, model__min_samples_leaf=5;, score=0.737 total time=  50.9s
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.08417312447616138, model__loss=absolute_error, model__max_leaf_nodes=85, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.08417312447616138, model__loss=absolute_error, model__max_leaf_nodes=85, model__min_samples_leaf=5;, score=0.749 total time=  50.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=2.2419993056685125e-05, model__learning_rate=1.1121574553993948e-05, model__loss=absolute_error, model__max_leaf_nodes=16, model__min_samples_leaf=583
# [CV 1/3; 1/1] END model__l2_regularization=2.2419993056685125e-05, model__learning_rate=1.1121574553993948e-05, model__loss=absolute_error, model__max_leaf_nodes=16, model__min_samples_leaf=583;, score=0.262 total time=   3.5s
# [CV 2/3; 1/1] START model__l2_regularization=2.2419993056685125e-05, model__learning_rate=1.1121574553993948e-05, model__loss=absolute_error, model__max_leaf_nodes=16, model__min_samples_leaf=583
# [CV 2/3; 1/1] END model__l2_regularization=2.2419993056685125e-05, model__learning_rate=1.1121574553993948e-05, model__loss=absolute_error, model__max_leaf_nodes=16, model__min_samples_leaf=583;, score=0.255 total time=   3.5s
# [CV 3/3; 1/1] START model__l2_regularization=2.2419993056685125e-05, model__learning_rate=1.1121574553993948e-05, model__loss=absolute_error, model__max_leaf_nodes=16, model__min_samples_leaf=583
# [CV 3/3; 1/1] END model__l2_regularization=2.2419993056685125e-05, model__learning_rate=1.1121574553993948e-05, model__loss=absolute_error, model__max_leaf_nodes=16, model__min_samples_leaf=583;, score=0.249 total time=   3.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=0.1256445715343005, model__learning_rate=0.006380764223004413, model__loss=squared_error, model__max_leaf_nodes=131, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=0.1256445715343005, model__learning_rate=0.006380764223004413, model__loss=squared_error, model__max_leaf_nodes=131, model__min_samples_leaf=5;, score=0.741 total time= 1.2min
# [CV 2/3; 1/1] START model__l2_regularization=0.1256445715343005, model__learning_rate=0.006380764223004413, model__loss=squared_error, model__max_leaf_nodes=131, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=0.1256445715343005, model__learning_rate=0.006380764223004413, model__loss=squared_error, model__max_leaf_nodes=131, model__min_samples_leaf=5;, score=0.745 total time= 1.2min
# [CV 3/3; 1/1] START model__l2_regularization=0.1256445715343005, model__learning_rate=0.006380764223004413, model__loss=squared_error, model__max_leaf_nodes=131, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=0.1256445715343005, model__learning_rate=0.006380764223004413, model__loss=squared_error, model__max_leaf_nodes=131, model__min_samples_leaf=5;, score=0.755 total time= 1.4min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.018881163432494994, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.018881163432494994, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.748 total time= 1.8min
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.018881163432494994, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.018881163432494994, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.749 total time= 1.3min
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.018881163432494994, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.018881163432494994, model__loss=squared_error, model__max_leaf_nodes=150, model__min_samples_leaf=5;, score=0.761 total time= 1.2min
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=4.699330261504698e-06, model__learning_rate=0.0058540436113708435, model__loss=squared_error, model__max_leaf_nodes=76, model__min_samples_leaf=6
# [CV 1/3; 1/1] END model__l2_regularization=4.699330261504698e-06, model__learning_rate=0.0058540436113708435, model__loss=squared_error, model__max_leaf_nodes=76, model__min_samples_leaf=6;, score=0.740 total time=  41.6s
# [CV 2/3; 1/1] START model__l2_regularization=4.699330261504698e-06, model__learning_rate=0.0058540436113708435, model__loss=squared_error, model__max_leaf_nodes=76, model__min_samples_leaf=6
# [CV 2/3; 1/1] END model__l2_regularization=4.699330261504698e-06, model__learning_rate=0.0058540436113708435, model__loss=squared_error, model__max_leaf_nodes=76, model__min_samples_leaf=6;, score=0.742 total time=  41.1s
# [CV 3/3; 1/1] START model__l2_regularization=4.699330261504698e-06, model__learning_rate=0.0058540436113708435, model__loss=squared_error, model__max_leaf_nodes=76, model__min_samples_leaf=6
# [CV 3/3; 1/1] END model__l2_regularization=4.699330261504698e-06, model__learning_rate=0.0058540436113708435, model__loss=squared_error, model__max_leaf_nodes=76, model__min_samples_leaf=6;, score=0.759 total time=  47.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=5.171466657455304e-06, model__learning_rate=0.003777672356503091, model__loss=squared_error, model__max_leaf_nodes=6, model__min_samples_leaf=9
# [CV 1/3; 1/1] END model__l2_regularization=5.171466657455304e-06, model__learning_rate=0.003777672356503091, model__loss=squared_error, model__max_leaf_nodes=6, model__min_samples_leaf=9;, score=0.634 total time=   3.8s
# [CV 2/3; 1/1] START model__l2_regularization=5.171466657455304e-06, model__learning_rate=0.003777672356503091, model__loss=squared_error, model__max_leaf_nodes=6, model__min_samples_leaf=9
# [CV 2/3; 1/1] END model__l2_regularization=5.171466657455304e-06, model__learning_rate=0.003777672356503091, model__loss=squared_error, model__max_leaf_nodes=6, model__min_samples_leaf=9;, score=0.636 total time=   3.9s
# [CV 3/3; 1/1] START model__l2_regularization=5.171466657455304e-06, model__learning_rate=0.003777672356503091, model__loss=squared_error, model__max_leaf_nodes=6, model__min_samples_leaf=9
# [CV 3/3; 1/1] END model__l2_regularization=5.171466657455304e-06, model__learning_rate=0.003777672356503091, model__loss=squared_error, model__max_leaf_nodes=6, model__min_samples_leaf=9;, score=0.653 total time=   3.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.24726671149310595, model__loss=absolute_error, model__max_leaf_nodes=72, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.24726671149310595, model__loss=absolute_error, model__max_leaf_nodes=72, model__min_samples_leaf=5;, score=0.724 total time=  42.8s
# [CV 2/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.24726671149310595, model__loss=absolute_error, model__max_leaf_nodes=72, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.24726671149310595, model__loss=absolute_error, model__max_leaf_nodes=72, model__min_samples_leaf=5;, score=0.731 total time=  42.7s
# [CV 3/3; 1/1] START model__l2_regularization=1e-06, model__learning_rate=0.24726671149310595, model__loss=absolute_error, model__max_leaf_nodes=72, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1e-06, model__learning_rate=0.24726671149310595, model__loss=absolute_error, model__max_leaf_nodes=72, model__min_samples_leaf=5;, score=0.733 total time=  42.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.02806356811310036, model__loss=squared_error, model__max_leaf_nodes=81, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.02806356811310036, model__loss=squared_error, model__max_leaf_nodes=81, model__min_samples_leaf=5;, score=0.756 total time=  39.7s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.02806356811310036, model__loss=squared_error, model__max_leaf_nodes=81, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.02806356811310036, model__loss=squared_error, model__max_leaf_nodes=81, model__min_samples_leaf=5;, score=0.754 total time=  39.3s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.02806356811310036, model__loss=squared_error, model__max_leaf_nodes=81, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.02806356811310036, model__loss=squared_error, model__max_leaf_nodes=81, model__min_samples_leaf=5;, score=0.761 total time=  38.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.013254702867477684, model__loss=squared_error, model__max_leaf_nodes=71, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.013254702867477684, model__loss=squared_error, model__max_leaf_nodes=71, model__min_samples_leaf=5;, score=0.751 total time=  37.2s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.013254702867477684, model__loss=squared_error, model__max_leaf_nodes=71, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.013254702867477684, model__loss=squared_error, model__max_leaf_nodes=71, model__min_samples_leaf=5;, score=0.747 total time=  38.7s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.013254702867477684, model__loss=squared_error, model__max_leaf_nodes=71, model__min_samples_leaf=5
# ...
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.015965915467854724, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.015965915467854724, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.765 total time=  43.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.015768432898781316, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.015768432898781316, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.756 total time=  43.4s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.015768432898781316, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.015768432898781316, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.744 total time=  43.6s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.015768432898781316, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.015768432898781316, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.758 total time=  43.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.01656383148227804, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.01656383148227804, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5;, score=0.757 total time=  43.3s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.01656383148227804, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.01656383148227804, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5;, score=0.752 total time=  43.6s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.01656383148227804, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.01656383148227804, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5;, score=0.766 total time=  43.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.016438865403492587, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.016438865403492587, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5;, score=0.753 total time=  43.5s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.016438865403492587, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.016438865403492587, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5;, score=0.754 total time=  43.6s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.016438865403492587, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.016438865403492587, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5;, score=0.760 total time=  43.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.016456579949952883, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.016456579949952883, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5;, score=0.756 total time=  43.8s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.016456579949952883, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.016456579949952883, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5;, score=0.745 total time=  43.9s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.016456579949952883, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.016456579949952883, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5;, score=0.760 total time=  43.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.01710111365720739, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.01710111365720739, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5;, score=0.757 total time=  43.2s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.01710111365720739, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.01710111365720739, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5;, score=0.745 total time=  43.7s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.01710111365720739, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.01710111365720739, model__loss=squared_error, model__max_leaf_nodes=87, model__min_samples_leaf=5;, score=0.772 total time=  43.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.017201561819382313, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.017201561819382313, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.750 total time=  43.1s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.017201561819382313, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.017201561819382313, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.751 total time=  43.0s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.017201561819382313, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.017201561819382313, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.766 total time=  48.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=0.00011387083516849397, model__learning_rate=0.11954974345989115, model__loss=squared_error, model__max_leaf_nodes=41, model__min_samples_leaf=6
# [CV 1/3; 1/1] END model__l2_regularization=0.00011387083516849397, model__learning_rate=0.11954974345989115, model__loss=squared_error, model__max_leaf_nodes=41, model__min_samples_leaf=6;, score=0.756 total time=  18.4s
# [CV 2/3; 1/1] START model__l2_regularization=0.00011387083516849397, model__learning_rate=0.11954974345989115, model__loss=squared_error, model__max_leaf_nodes=41, model__min_samples_leaf=6
# [CV 2/3; 1/1] END model__l2_regularization=0.00011387083516849397, model__learning_rate=0.11954974345989115, model__loss=squared_error, model__max_leaf_nodes=41, model__min_samples_leaf=6;, score=0.735 total time=  18.4s
# [CV 3/3; 1/1] START model__l2_regularization=0.00011387083516849397, model__learning_rate=0.11954974345989115, model__loss=squared_error, model__max_leaf_nodes=41, model__min_samples_leaf=6
# [CV 3/3; 1/1] END model__l2_regularization=0.00011387083516849397, model__learning_rate=0.11954974345989115, model__loss=squared_error, model__max_leaf_nodes=41, model__min_samples_leaf=6;, score=0.744 total time=  18.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.016546927645312983, model__loss=squared_error, model__max_leaf_nodes=89, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.016546927645312983, model__loss=squared_error, model__max_leaf_nodes=89, model__min_samples_leaf=5;, score=0.757 total time=  44.3s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.016546927645312983, model__loss=squared_error, model__max_leaf_nodes=89, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.016546927645312983, model__loss=squared_error, model__max_leaf_nodes=89, model__min_samples_leaf=5;, score=0.748 total time=  44.4s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.016546927645312983, model__loss=squared_error, model__max_leaf_nodes=89, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.016546927645312983, model__loss=squared_error, model__max_leaf_nodes=89, model__min_samples_leaf=5;, score=0.763 total time=  44.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.014985228842882526, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.014985228842882526, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.756 total time=  44.7s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.014985228842882526, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.014985228842882526, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.754 total time=  43.7s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.014985228842882526, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.014985228842882526, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.759 total time=  43.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.014824567135285776, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.014824567135285776, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.752 total time=  43.5s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.014824567135285776, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.014824567135285776, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.750 total time=  43.4s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.014824567135285776, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.014824567135285776, model__loss=squared_error, model__max_leaf_nodes=86, model__min_samples_leaf=5;, score=0.764 total time=  43.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.01722968094269431, model__loss=squared_error, model__max_leaf_nodes=90, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.01722968094269431, model__loss=squared_error, model__max_leaf_nodes=90, model__min_samples_leaf=5;, score=0.753 total time=  44.6s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.01722968094269431, model__loss=squared_error, model__max_leaf_nodes=90, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.01722968094269431, model__loss=squared_error, model__max_leaf_nodes=90, model__min_samples_leaf=5;, score=0.745 total time=  44.5s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.01722968094269431, model__loss=squared_error, model__max_leaf_nodes=90, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.01722968094269431, model__loss=squared_error, model__max_leaf_nodes=90, model__min_samples_leaf=5;, score=0.767 total time=  44.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=0.17417817342248582, model__learning_rate=0.22733496793341684, model__loss=squared_error, model__max_leaf_nodes=46, model__min_samples_leaf=9
# [CV 1/3; 1/1] END model__l2_regularization=0.17417817342248582, model__learning_rate=0.22733496793341684, model__loss=squared_error, model__max_leaf_nodes=46, model__min_samples_leaf=9;, score=0.726 total time=  19.7s
# [CV 2/3; 1/1] START model__l2_regularization=0.17417817342248582, model__learning_rate=0.22733496793341684, model__loss=squared_error, model__max_leaf_nodes=46, model__min_samples_leaf=9
# [CV 2/3; 1/1] END model__l2_regularization=0.17417817342248582, model__learning_rate=0.22733496793341684, model__loss=squared_error, model__max_leaf_nodes=46, model__min_samples_leaf=9;, score=0.723 total time=  19.7s
# [CV 3/3; 1/1] START model__l2_regularization=0.17417817342248582, model__learning_rate=0.22733496793341684, model__loss=squared_error, model__max_leaf_nodes=46, model__min_samples_leaf=9
# [CV 3/3; 1/1] END model__l2_regularization=0.17417817342248582, model__learning_rate=0.22733496793341684, model__loss=squared_error, model__max_leaf_nodes=46, model__min_samples_leaf=9;, score=0.732 total time=  19.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.014775510611505163, model__loss=squared_error, model__max_leaf_nodes=84, model__min_samples_leaf=5
# [CV 1/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.014775510611505163, model__loss=squared_error, model__max_leaf_nodes=84, model__min_samples_leaf=5;, score=0.751 total time=  42.3s
# [CV 2/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.014775510611505163, model__loss=squared_error, model__max_leaf_nodes=84, model__min_samples_leaf=5
# [CV 2/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.014775510611505163, model__loss=squared_error, model__max_leaf_nodes=84, model__min_samples_leaf=5;, score=0.746 total time=  42.3s
# [CV 3/3; 1/1] START model__l2_regularization=1.0, model__learning_rate=0.014775510611505163, model__loss=squared_error, model__max_leaf_nodes=84, model__min_samples_leaf=5
# [CV 3/3; 1/1] END model__l2_regularization=1.0, model__learning_rate=0.014775510611505163, model__loss=squared_error, model__max_leaf_nodes=84, model__min_samples_leaf=5;, score=0.760 total time=  42.3s

# %%
import dill

with open("base_model_with_stats/fitted_model.pk", "wb") as file:
    dill.dump(bs_model, file)

with open("base_model_with_stats/ids_train_test.pk", "wb") as file:
    dill.dump({"train": id_train,
              "test": id_test}, file)

# %% [markdown]
# ### Performance plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.regplot(x=y_test, y=y_pred, line_kws=dict(color="r"), lowess=True)
plt.plot(y_test, y_test, color="black", linestyle="--", label="perfect regression")
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.legend()
plt.savefig("base_model_with_stats/fig1.png", dpi=400)
plt.show()

# %%
sns.regplot(x=y_test, y=np.abs(y_test - y_pred),
            lowess=True, line_kws=dict(color="r"))
plt.xlabel("y_test")
plt.ylabel("|y_test - y_pred|")
plt.savefig("base_model_with_stats/fig2.png", dpi=400)
plt.show()

# %%
sns.regplot(x=y_test, y=y_pred - y_test,
            lowess=True, line_kws=dict(color="r"))
plt.plot(y_test, [np.log10(1.20)]*len(y_test), color="black",
         linestyle="--",
         label="20% error box")
plt.plot(y_test, [np.log10(0.80)]*len(y_test), color="black",
         linestyle="--")
plt.xlabel("y_test")
plt.ylabel("y_pred - y_test")
plt.legend()
plt.savefig("base_model_with_stats/fig3.png", dpi=400)
plt.show()

# %%
plt.hist(y_pred - y_test, bins=250)
plt.xlabel("y_pred - y_test")
plt.savefig("base_model_with_stats/fig4.png", dpi=400)
plt.show()

# %% [markdown]
# The score below tells the percentage of the test that for which there is a maximum of 20% error. Note that we achieved a significant improvement compared to the base model.

# %%
scoring(y_test, y_pred)
# Out:
# 0.7661870503597122
